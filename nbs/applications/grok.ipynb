# %%
from irouter import Chat
from IPython.display import Image, display
from dotenv import load_dotenv

load_dotenv();

# %% [markdown]
# # Grok
#
# ## Simple chat
#
# `irouter` allows you to use any LLM in openrouter.ai with minimal lines of code.

# %%
c = Chat("x-ai/grok-4.20")
c("Who created you?")
# Out:
# '**I was created by xAI.**\n\nxAI is the company founded by Elon Musk, and I was developed by their team (with a lot of help from Grok\'s "parents" — the original Grok-1 model and subsequent versions). \n\nI\'m the latest version: **Grok 4**.'

# %%
c.usage
# Out:
# {'prompt_tokens': 135, 'completion_tokens': 62, 'total_tokens': 197}

# %% [markdown]
# ## Image

# %%
image_url = "https://assets.elanco.com/8e0bf1c2-1ae4-001f-9257-f2be3c683fb1/2366147c-9d05-4414-b016-2bd0e3233b1a/shutterstock_97506335_0.jpg?w=1920&q=75&auto=format"
display(Image(url=image_url, width=300))
# Out:
# <img src="https://assets.elanco.com/8e0bf1c2-1ae4-001f-9257-f2be3c683fb1/2366147c-9d05-4414-b016-2bd0e3233b1a/shutterstock_97506335_0.jpg?w=1920&q=75&auto=format" width="300"/>

# %%
print(c([image_url, "What is in this image?"]))
# Out:
# **Here's what's in the image:**
#
# There are **six adorable kittens** sitting inside three colorful pots.
#
# From left to right:
#
# - **Light blue pot**: Two kittens
#   - A gray tabby with white chest
#   - An orange tabby kitten
#
# - **Lime green pot**: Two kittens
#   - A ginger/orange kitten
#   - A gray tabby kitten in the middle
#
# - **Pink pot**: Two kittens
#   - An orange and white kitten
#   - Another orange and white kitten
#
# All six kittens are looking directly at the camera with big, cute eyes and tiny paws resting on the rims of the pots. The background is a solid, bright yellow-green color.
#
# It's a very popular cute kitten photo! 🐱

# %% [markdown]
# ## Multi Agent + Web Search
#
# In this example we combine Grok's multi-agent capabilities with web search to find the best hotel for our ski trip.
#
# NOTE: Multi-agent can get expensive. The call below costs me $0.40, event with low reasoning effort.

# %%
c = Chat("x-ai/grok-4.20-multi-agent:online")

# %%
r = c("What is the best hotel I can book in Sierra Nevada for 15-19 april under 1000 euros?", extra_body={"reasoning": {"effort": "low"}})

# %%
print(r)
# Out:
# **Meliá Sol y Nieve (or the very similar Meliá Sierra Nevada) is the strongest recommendation for a proper hotel in the Pradollano ski resort area that fits (or comes close to) your budget.**[[1]](https://www.tripadvisor.com/HotelsList-Sierra_Nevada_National_Park-Ski-Hotels-zfp33922398.html)
#
# ### Why this hotel?
# - **Location**: In the heart of Pradollano (the main Sierra Nevada ski village), with excellent ski-to-door or very short walk access to the main lifts, cable car, and slopes. Perfect base for skiing or spring activities.[[2]](https://www.booking.com/city/es/sierra-nevada.html)
# - **Quality & amenities**: 4-star hotel with spa, multiple restaurants (including buffet), good breakfast, ski storage/rental options, and solid facilities. It has repeatedly been recognized as one of Spain’s top ski hotels. Reviews praise the location (often 9.5+), service, and convenience for a ski trip. Overall Booking.com scores are typically in the 8.5 range; it ranks highly on Tripadvisor for ski hotels in the area.[[1]](https://www.tripadvisor.com/HotelsList-Sierra_Nevada_National_Park-Ski-Hotels-zfp33922398.html)
# - **Price outlook**: Late-season April rates (ski season usually runs until early May) are lower than peak winter. Recent/seasonal snippets show roughly €200–300 per night for a standard double room (≈ $230–330). For 4 nights this often lands in the €800–1100 range total before taxes/fees for 2 adults. A standard room or any current deal could keep it comfortably **under €1000 total**—check immediately as it’s only ~2 weeks away.[[3]](https://www.expedia.com/Monachil-Hotels-Melia-Sol-Y-Nieve.h874019.Hotel-Information)
#
# ### Luxury options (probably over budget)
# - **Hotel Maribel** and **El Lodge Ski & Spa** are the highest-rated luxury properties (9.0–9.3 on Booking, excellent spa/pool/ski-in-ski-out access, boutique feel). They are widely considered the “best” overall but typically start at €250–400+ per night (El Lodge often €380+). Four nights would likely exceed €1000 (sometimes significantly).[[4]](https://marbellaprestige.realestate/skiing-sierra-nevada-luxury-spots/)
#
# ### Other good alternatives under €1000
# - **Inside Plaza Sierra Nevada** (aparthotel/apartments): Very well reviewed (4.5 on Tripadvisor), modern, great views, central location, and often better value than traditional hotels. Good if you want kitchen facilities.[[5]](https://www.tripadvisor.com/HotelsList-Sierra_Nevada-Ski-Hotels-zfp12362050.html)
# - Cheaper well-rated options (8.8–9.0+) include Hotel Kenia Nevada (has pool/spa) or various apartments in Pradollano from ~€150–220/night.
#
# ### Recommendations
# - Book via **Booking.com** or the official Meliá site with your exact dates (15–19 April 2026, 2 adults) to see real-time pricing and availability. Filter for “Sierra Nevada” or “Pradollano” specifically (avoid Granada city hotels).[[2]](https://www.booking.com/city/es/sierra-nevada.html)
# - April is late season: expect possible spring snow/slush but the resort is normally open. Confirm snow conditions and opening dates.
# - Add ski passes, equipment rental, or half-board if offered for convenience.
#
# **Quick action**: Search your dates on Booking.com or Kayak right now—Meliá Sol y Nieve / Sierra Nevada is the best balance of quality, location, and price for a real hotel under (or very close to) your €1000 limit. If the exact quote is over, go for Inside Plaza or a high-rated apartment in the same area. Let me know if you need links or help checking specific room types!
